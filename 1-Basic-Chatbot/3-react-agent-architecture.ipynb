# %%
from typing import Annotated

from typing_extensions import TypedDict

from langgraph.graph import StateGraph,START,END
from langgraph.graph.message import add_messages

# %%
class State(TypedDict):
    # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages:Annotated[list,add_messages]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain.chat_models import init_chat_model
llm=init_chat_model("groq:llama-3.1-8b-instant")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000002566AA94A40>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002566AC012B0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_tavily import TavilySearch

tool=TavilySearch(max_results=2)

# %%
## Custom function
def multiply(a:int,b:int)->int:
    """Multiply a and b

    Args:
        a (int): first int
        b (int): second int

    Returns:
        int: output int
    """
    return a*b

# %%
## Custom function
def add(a:int,b:int)->int:
    """Add a and b

    Args:
        a (int): first int
        b (int): second int

    Returns:
        int: output int
    """
    return a+b

# %%
## Custom function
def subtract(a:int,b:int)->int:
    """Subtract b from a

    Args:
        a (int): first int
        b (int): second int

    Returns:
        int: output int
    """
    return a-b

# %%
tools=[tool,multiply,add,subtract]

# %%
llm_using_tools=llm.bind_tools(tools)

# %%
## Stategraph
from langgraph.graph import StateGraph,START,END
from langgraph.prebuilt import ToolNode
from langgraph.prebuilt import tools_condition

## Node definition
def llm_calling_tools(state:State):
    return {"messages":[llm_using_tools.invoke(state["messages"])]}

## Grpah
builder=StateGraph(State)
builder.add_node("llm_calling_tools",llm_calling_tools)
builder.add_node("tools",ToolNode(tools))

## Add Edges
builder.add_edge(START, "llm_calling_tools")
builder.add_conditional_edges(
    "llm_calling_tools",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition
)
builder.add_edge("tools","llm_calling_tools")

## compile the graph
graph=builder.compile()

from IPython.display import Image, display
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
response=graph.invoke({"messages":"What is the recent news about Apple and also multiply 5 with 6 and add 10 to the result and subtract 3 from the final result?"})

# %%
for m in response['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the recent news about Apple and also multiply 5 with 6 and add 10 to the result and subtract 3 from the final result?
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (b7nw49qg9)
#  Call ID: b7nw49qg9
#   Args:
#     query: Apple recent news
#     search_depth: advanced
#     topic: news
#   multiply (f0nv0mjfn)
#  Call ID: f0nv0mjfn
#   Args:
#     a: 5
#     b: 6
#   add (aq522wfse)
#  Call ID: aq522wfse
#   Args:
#     a: 30
#     b: 10
#   subtract (t2pf92mbb)
#  Call ID: t2pf92mbb
#   Args:
#     a: 40
#     b: 3
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "Apple recent news", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.geeky-gadgets.com/iphone-18-pro-max-camera-upgrade/", "title": "Apple’s Biggest Camera Jump Ever: The iPhone 18 Pro Max Brings Pro-Level Glass to Your Pocket - Geeky Gadgets", "score": 0.9683812, "published_date": "Sat, 11 Apr 2026 15:00:46 GMT", "content": "Skip to secondary menu\n Skip to primary sidebar\n Skip to footer\n\nGeeky Gadgets\n\nThe Latest Technology News\n\n  \n  \n\n# Apple’s Biggest Camera Jump Ever: The iPhone 18 Pro Max Brings Pro-Level Glass to Your Pocket\n\nBy Roland Hutchinson\n\nThe iPhone 18 Pro Max represents a pivotal moment in Apple’s flagship smartphone lineup. With its focus on innovative camera technology, improved battery performance and enhanced connectivity, the device is designed to deliver a superior user experience. Apple is also introducing a new release strategy, featuring a staggered launch schedule that includes the standard iPhone 18 in spring and a foldable iPhone later in the year. These changes reflect Apple’s evolving approach to innovation and its efforts to maintain a competitive edge in the smartphone market. [...] For the foldable iPhone, Apple has introduced a dual-battery system designed to optimize power management. This innovation ensures that the foldable device remains reliable and efficient, even with its unique form factor. These performance and battery improvements highlight Apple’s focus on delivering practical enhancements that meet the demands of modern users.\n\n## Connectivity: Bridging the Gaps [...] Watch this video on YouTube.\n\n## Apple’s New Launch Strategy\n\nApple is redefining its product release timeline to sustain consumer interest throughout the year. The iPhone 18 Pro and Pro Max will adhere to the traditional September launch, targeting users who prioritize premium features and performance. However, the standard iPhone 18 will debut in spring, breaking away from the usual fall release pattern. This shift ensures that Apple remains in the spotlight during different seasons.\n\nAdditionally, Apple is preparing to unveil its first foldable iPhone in December, marking its entry into the foldable smartphone segment. This staggered approach not only diversifies Apple’s product offerings but also positions the company as a consistent innovator in the tech industry.", "raw_content": null}, {"url": "https://www.cultofmac.com/news/folding-iphone-rumors-new-images", "title": "Apple’s folding iPhone redesign looks stunning in new images - Cult of Mac", "score": 0.9656413, "published_date": "Mon, 06 Apr 2026 14:48:12 GMT", "content": "News\n  + Apple rumors and leaks\n  + Apple Intelligence\n  + Apple silicon\n  + Apple patents\n  + AAPL\n  + Apple events\n  + WWDC\n  + Editor's picks\n  + More news ...\n ReviewsHere at Cult of Mac, we regularly review Apple products and other tech gear and accessories. We also frequently write about Apple TV+ offerings. If we receive a review unit, we disclose it. (Read our reviews policy.) We frequently employ affiliate links. If you purchase a product after clicking a link from our website, we might earn a commission.\n  + iPhone reviews\n  + iPad reviews\n  + Mac reviews\n  + Apple Watch reviews\n  + Vision Pro reviews\n  + AirPods reviews\n  + Apple TV reviews\n How-To\n  + Setups\n  + iPhone how-tos\n  + iPad how-tos\n  + Mac how-tos\n  + Apple Watch how-tos\n  + Vision Pro how-tos\n  + AirPods how-tos [...] News\n  + Apple rumors and leaks\n  + Apple Intelligence\n  + Apple silicon\n  + Apple patents\n  + AAPL\n  + Apple events\n  + WWDC\n  + Editor's picks\n  + More news ...\n ReviewsHere at Cult of Mac, we regularly review Apple products and other tech gear and accessories. We also frequently write about Apple TV+ offerings. If we receive a review unit, we disclose it. (Read our reviews policy.) We frequently employ affiliate links. If you purchase a product after clicking a link from our website, we ...
# ================================= Tool Message =================================
# Name: multiply
#
# 30
# ================================= Tool Message =================================
# Name: add
#
# 40
# ================================= Tool Message =================================
# Name: subtract
#
# 37
# ================================== Ai Message ==================================
#
# The recent news about Apple includes the announcement of their new iPhone 18 Pro Max with improved camera technology, a new release strategy, and a foldable iPhone that will be released in December.
